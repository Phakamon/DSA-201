# %%
def hello_func(name):
    for n in name:
        print("Hello",n,"!")
        name[0] = 'Conan'
        name[1] = 'Subaru'
        name[2] = 'Zero'
name = ['Shinici', 'Akai' ,'Amuro']
hello_func(name)

print("The names are now",name)
# Out:
# Hello Shinici !
# Hello Subaru !
# Hello Zero !
# The names are now ['Conan', 'Subaru', 'Zero']

# %%
def area_of_rectangle(width,height):
    area = width*height
    print("The area of rectangle is ",area)
area_of_rectangle(8,6)
# Out:
# The area of rectangle is  48

# %%
#uesr Input
rectangle_width = int(input())
rectangle_height = int(input())
k = rectangle_width * rectangle_height
print("The answer is ",k)
# Out:
#  5
#  7
# the answer is  35

# %%
def fibonacci():
    round = int(input("Enter number of round is "))
    a = 0
    b = 1
    for i in range(1,round):
        c = a+b
        a = b
        b = c
        print(c)
fibonacci()
# Out:
# Enter number of round is  5
# 1
# 2
# 3
# 5

# %%
def area_of_rectangle():
    width = int(input("Enter number(width):"))
    height = int(input ("'Enter number(height):"))
    area = width*height
    print("The area of rectangle is ",area)
area_of_rectangle()
# Out:
# Enter number(width): 5
# 'Enter number(height): 8
# The area of rectangle is  40

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (0.25.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.16.5)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 0.25.1

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.7.4.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# machine          : AMD64
# processor        : Intel64 Family 6 Model 142 Stepping 11, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : None.None
#
# pandas           : 0.25.1
# numpy            : 1.16.5
# pytz             : 2019.3
# dateutil         : 2.8.0
# pip              : 19.2.3
# setuptools       : 41.4.0
# Cython           : 0.29.13
# pytest           : 5.2.1
# hypothesis       : None
# sphinx           : 2.2.0
# blosc            : None
# feather          : None
# xlsxwriter       : 1.2.1
# lxml.etree       : 4.4.1
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.10.3
# IPython          : 7.8.0
# pandas_datareader: 0.8.1
# bs4              : 4.8.0
# bottleneck       : 1.2.1
# fastparquet      : None
# gcsfs            : None
# lxml.etree       : 4.4.1
# matplotlib       : 3.1.1
# numexpr          : 2.7.0
# odfpy            : None
# openpyxl         : 3.0.0
# pandas_gbq       : None
# pyarrow          : None
# pytables         : None
# s3fs             : None
# scipy            : 1.3.1
# sqlalchemy       : 1.3.9
# tables           : 3.5.2
# xarray           : None
# xlrd             : 1.2.0
# xlwt             : 1.3.0
# xlsxwriter       : 1.2.1

# %%
data = {
    'apples':[3,2,0,1],
    'oranges':[0,3,7,2]}
purchase = pd.DataFrame(data)
purchase
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchase = pd.DataFrame(data,index=['June','Robert','Lily','David'])
purchase
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchase.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
url ='https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/purchases.csv'
df = pd.read_csv(url, error_bad_lines = False)
df
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
url ='https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/purchases.csv'
df = pd.read_csv(url, error_bad_lines = False, index_col =0)
df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
df.to_json('new_purchases.json')

# %%
df = pd.read_json('new_purchases.json')
df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
movies_df = pd.read_csv("IMDB movies.csv",index_col="title")
movies_df
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                imdb_title_id                  original_title  \
# title
# Miss Jerry                         tt0000009                      Miss Jerry
# The Story of the Kelly Gang        tt0000574     The Story of the Kelly Gang
# Den sorte drøm                     tt0001892                  Den sorte drøm
# Cleopatra                          tt0002101                       Cleopatra
# L'Inferno                          tt0002130                       L'Inferno
# ...                                      ...                             ...
# Le lion                            tt9908390                         Le lion
# De Beentjes van Sint-Hildegard     tt9911196  De Beentjes van Sint-Hildegard
# Padmavyuhathile Abhimanyu          tt9911774       Padmavyuhathile Abhimanyu
# Sokagin Çocuklari                  tt9914286               Sokagin Çocuklari
# La vida sense la Sara Amat         tt9914942      La vida sense la Sara Amat
#
#                                 year date_published  \
# title
# Miss Jerry                      1894     1894-10-09
# The Story of the Kelly Gang     1906     1906-12-26
# Den sorte drøm                  1911     1911-08-19
# Cleopatra                       1912     1912-11-13
# L'Inferno                       1911     1911-03-06
# ...                              ...            ...
# Le lion                         2020     2020-01-29
# De Beentjes van Sint-Hildegard  2020     2020-02-13
# Padmavyuhathile Abhimanyu       2019     2019-03-08
# Sokagin Çocuklari               2019     2019-03-15
# La vida sense la Sara Amat      2019     2020-02-05
#
#                                                     genre  duration  \
# title
# Miss Jerry                                        Romance        45
# The Story of the Kelly Gang       Biography, Crime, Drama        70
# Den sorte drøm                                      Drama        53
# Cleopatra                                  Drama, History       100
# L'Inferno                       Adventure, Drama, Fantasy        68
# ...                                                   ...       ...
# Le lion                                            Comedy        95
# De Beentjes van Sint-Hildegard              Comedy, Drama       103
# Padmavyuhathile Abhimanyu                           Drama       130
# Sokagin Çocuklari                           Drama, Family        98
# La vida sense la Sara Amat                          Drama        74
#
#                                          country       language  \
# title
# Miss Jerry                                   USA           None
# The Story of the Kelly Gang            Australia           None
# Den sorte drøm                  Germany, Denmark            NaN
# Cleopatra                                    USA        English
# L'Inferno                                  Italy        Italian
# ...                                          ...            ...
# Le lion                          France, Belgium         French
# De Beentjes van Sint-Hildegard       Netherlands  German, Dutch
# Padmavyuhathile Abhimanyu                  India      Malayalam
# Sokagin Çocuklari                         Turkey        Turkish
# La vida sense la Sara Amat                 Spain        Catalan
#
#                                                            director  \
# title
# Miss Jerry                                          Alexander Black
# The Story of the Kelly Gang                            Charles Tait
# Den sorte drøm                                            Urban Gad
# Cleopatra                                        Charles L. Gaskill
# L'Inferno                       Francesco Bertolini, Adolfo Padovan
# ...                                                             ...
# Le lion                                      Ludovic Colbeau-Justin
# De Beentjes van Sint-Hildegard                      Johan Nijenhuis
# Padmavyuhathile Abhimanyu                           Vineesh Aaradya
# Sokagin Çocuklari                                 Ahmet Faik Akinci
# La vida sense la Sara Amat                                Laura Jou
#
#                                                                writer  ...  \
# title                                                                  ...
# Miss Jerry                                            Alexander Black  ...
# The Story of the Kelly Gang                              Charles Tait  ...
# Den sorte drøm                  Urban Gad, Gebhard Schätzler-Perasini  ...
# Cleopatra                                            Victorien Sardou  ...
# L'Inferno                                             Dante Alighieri  ...
# ...                                                               ...  ...
# Le lion                         Alexandre Coquelle, Matthieu Le Naour  ...
# De Beentjes van Sint-Hildegard           Radek Bajgar, Herman Finkers  ...
# Padmavyuhathile Abhimanyu            Vineesh Aaradya, Vineesh Aaradya  ...
# Sokagin Çocuklari                      Ahmet Faik Akinci, Kasim Uçkan  ...
# La vida sense la Sara Amat                       Coral Cruz, Pep Puig  ...
#
#                                                                            actors  \
# title
# Miss Jerry                      Blanche Bayliss, William Courtenay, Chauncey D...
# The Story of the Kelly Gang     Elizabeth Tait, John Tait, Norman Campbell, Be...
# Den sorte drøm                  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# Cleopatra                       Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# L'Inferno                       Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# ...                                                                           ...
# Le lion                         Dany Boon, Philippe Katerine, Anne Serra, Samu...
# De Beentjes van Sint-Hildegard  Herman Finkers, Johanna ter Steege, Leonie ter...
# Padmavyuhathile Abhimanyu       Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# Sokagin Çocuklari               Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# La vida sense la Sara Amat      Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                                                       description  \
# title
# Miss Jerry                      The adventures of a female reporter in the 1890s.
# The Story of the Kelly Gang     True story of notorious Australian outlaw Ned ...
# Den sorte drøm                  Two men of high rank are both wooing the beaut...
# Cleopatra                       The fabled queen of Egypt's affair with Roman ...
# L'Inferno                       Loosely adapted from Dante's Divine Comedy and...
# ...                                                                           ...
# Le lion                         A psychiatric hospital patient pretends to be ...
# De Beentjes van Sint-Hildegard  A middle-aged veterinary surgeon believes his ...
# Padmavyuhathile Abhimanyu                                                     NaN
# Sokagin Çocuklari                                                             NaN
# La vida sense la Sara Amat      Pep, a 13-year-old boy, is in love with a girl...
#
#                                avg_vote  votes   budget usa_gross_income  \
# title
# Miss Jerry                          5.9    154      NaN              NaN
# The Story of the Kelly Gang         6.1    589   $ 2250              NaN
# Den sorte drøm                      5.8    188      NaN              NaN
# Cleopatra                           5.2    446  $ 45000              NaN
# L'Inferno                           7.0   2237      NaN              NaN
# ...                                 ...    ...      ...              ...
# Le lion                             5.3    398      NaN              NaN
# De Beentjes van Sint-Hildegard      7.7    724      NaN              NaN
# Padmavyuhathile Abhimanyu           7.9    265      NaN              NaN
# Sokagin Çocuklari                   6.4    194      NaN              NaN
# La vida sense la Sara Amat          6.7    102      NaN              NaN
#
#                                worlwide_gross_income metascore  \
# title
# Miss Jerry                                       NaN       NaN
# The Story of the Kelly Gang                      NaN       NaN
# Den sorte drøm                                   NaN       NaN
# Cleopatra                                        NaN       NaN
# L'Inferno                                        NaN       NaN
# ...                                              ...       ...
# Le lion                                    $ 3507171       NaN
# De Beentjes van Sint-Hildegard             $ 7299062       NaN
# Padmavyuhathile Abhimanyu                        NaN       NaN
# Sokagin Çocuklari                             $ 2833       NaN
# La vida sense la Sara Amat                   $ 59794       NaN
#
#                                 reviews_from_users  reviews_from_critics
# title
# Miss Jerry                                     1.0                   2.0
# The Story of the Kelly Gang                    7.0                   7.0
# Den sorte drøm                                 5.0                   2.0
# Cleopatra                                     25.0                   3.0
# L'Inferno                                     31.0                  14.0
# ...                                            ...                   ...
# Le lion                                        NaN                   4.0
# De Beentjes van Sint-Hildegard                 6.0                   4.0
# Padmavyuhathile Abhimanyu                      NaN                   NaN
# Sokagin Çocuklari                              NaN                   NaN
# La vida sense la Sara Amat                     NaN                   2.0
#
# [85855 rows x 21 columns]

# %%
movies_df.head()
# Out:
#                             imdb_title_id               original_title  year  \
# title
# Miss Jerry                      tt0000009                   Miss Jerry  1894
# The Story of the Kelly Gang     tt0000574  The Story of the Kelly Gang  1906
# Den sorte drøm                  tt0001892               Den sorte drøm  1911
# Cleopatra                       tt0002101                    Cleopatra  1912
# L'Inferno                       tt0002130                    L'Inferno  1911
#
#                             date_published                      genre  \
# title
# Miss Jerry                      1894-10-09                    Romance
# The Story of the Kelly Gang     1906-12-26    Biography, Crime, Drama
# Den sorte drøm                  1911-08-19                      Drama
# Cleopatra                       1912-11-13             Drama, History
# L'Inferno                       1911-03-06  Adventure, Drama, Fantasy
#
#                              duration           country language  \
# title
# Miss Jerry                         45               USA     None
# The Story of the Kelly Gang        70         Australia     None
# Den sorte drøm                     53  Germany, Denmark      NaN
# Cleopatra                         100               USA  English
# L'Inferno                          68             Italy  Italian
#
#                                                         director  \
# title
# Miss Jerry                                       Alexander Black
# The Story of the Kelly Gang                         Charles Tait
# Den sorte drøm                                         Urban Gad
# Cleopatra                                     Charles L. Gaskill
# L'Inferno                    Francesco Bertolini, Adolfo Padovan
#
#                                                             writer  ...  \
# title                                                               ...
# Miss Jerry                                         Alexander Black  ...
# The Story of the Kelly Gang                           Charles Tait  ...
# Den sorte drøm               Urban Gad, Gebhard Schätzler-Perasini  ...
# Cleopatra                                         Victorien Sardou  ...
# L'Inferno                                          Dante Alighieri  ...
#
#                                                                         actors  \
# title
# Miss Jerry                   Blanche Bayliss, William Courtenay, Chauncey D...
# The Story of the Kelly Gang  Elizabeth Tait, John Tait, Norman Campbell, Be...
# Den sorte drøm               Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# Cleopatra                    Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# L'Inferno                    Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                                                    description  \
# title
# Miss Jerry                   The adventures of a female reporter in the 1890s.
# The Story of the Kelly Gang  True story of notorious Australian outlaw Ned ...
# Den sorte drøm               Two men of high rank are both wooing the beaut...
# Cleopatra                    The fabled queen of Egypt's affair with Roman ...
# L'Inferno                    Loosely adapted from Dante's Divine Comedy and...
#
#                             avg_vote  votes   budget usa_gross_income  \
# title
# Miss Jerry                       5.9    154      NaN              NaN
# The Story of the Kelly Gang      6.1    589   $ 2250              NaN
# Den sorte drøm                   5.8    188      NaN              NaN
# Cleopatra                        5.2    446  $ 45000              NaN
# L'Inferno                        7.0   2237      NaN              NaN
#
#                             worlwide_gross_income metascore  \
# title
# Miss Jerry                                    NaN       NaN
# The Story of the Kelly Gang                   NaN       NaN
# Den sorte drøm                                NaN       NaN
# Cleopatra                                     NaN       NaN
# L'Inferno                                     NaN       NaN
#
#                              reviews_from_users  reviews_from_critics
# title
# Miss Jerry                                  1.0                   2.0
# The Story of the Kelly Gang                 7.0                   7.0
# Den sorte drøm                              5.0                   2.0
# Cleopatra                                  25.0                   3.0
# L'Inferno                                  31.0                  14.0
#
# [5 rows x 21 columns]

# %%
movies_df.tail(2)
# Out:
#                            imdb_title_id              original_title  year  \
# title
# Sokagin Çocuklari              tt9914286           Sokagin Çocuklari  2019
# La vida sense la Sara Amat     tt9914942  La vida sense la Sara Amat  2019
#
#                            date_published          genre  duration country  \
# title
# Sokagin Çocuklari              2019-03-15  Drama, Family        98  Turkey
# La vida sense la Sara Amat     2020-02-05          Drama        74   Spain
#
#                            language           director  \
# title
# Sokagin Çocuklari           Turkish  Ahmet Faik Akinci
# La vida sense la Sara Amat  Catalan          Laura Jou
#
#                                                     writer  ...  \
# title                                                       ...
# Sokagin Çocuklari           Ahmet Faik Akinci, Kasim Uçkan  ...
# La vida sense la Sara Amat            Coral Cruz, Pep Puig  ...
#
#                                                                        actors  \
# title
# Sokagin Çocuklari           Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# La vida sense la Sara Amat  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                                                   description  \
# title
# Sokagin Çocuklari                                                         NaN
# La vida sense la Sara Amat  Pep, a 13-year-old boy, is in love with a girl...
#
#                            avg_vote  votes  budget usa_gross_income  \
# title
# Sokagin Çocuklari               6.4    194     NaN              NaN
# La vida sense la Sara Amat      6.7    102     NaN              NaN
#
#                            worlwide_gross_income metascore  \
# title
# Sokagin Çocuklari                         $ 2833       NaN
# La vida sense la Sara Amat               $ 59794       NaN
#
#                             reviews_from_users  reviews_from_critics
# title
# Sokagin Çocuklari                          NaN                   NaN
# La vida sense la Sara Amat                 NaN                   2.0
#
# [2 rows x 21 columns]

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85855 entries, Miss Jerry to La vida sense la Sara Amat
# Data columns (total 21 columns):
# imdb_title_id            85855 non-null object
# original_title           85855 non-null object
# year                     85855 non-null object
# date_published           85855 non-null object
# genre                    85855 non-null object
# duration                 85855 non-null int64
# country                  85791 non-null object
# language                 85022 non-null object
# director                 85768 non-null object
# writer                   84283 non-null object
# production_company       81400 non-null object
# actors                   85786 non-null object
# description              83740 non-null object
# avg_vote                 85855 non-null float64
# votes                    85855 non-null int64
# budget                   23710 non-null object
# usa_gross_income         15326 non-null object
# worlwide_gross_income    31016 non-null object
# metascore                13305 non-null float64
# reviews_from_users       78258 non-null float64
# reviews_from_critics     74058 non-null float64
# dtypes: float64(4), int64(2), object(15)
# memory usage: 14.4+ MB

# %%
movies_df.shape
# Out:
# (85855, 21)

# %%
temp_df = movies_df.append(movies_df)
temp_df.shape
# Out:
# (171710, 21)

# %%
temp_df.drop_duplicates(inplace=True)
print(temp_df.shape)
temp_df.head(2)
# Out:
# (85855, 21)
#                             imdb_title_id               original_title  year  \
# title
# Miss Jerry                      tt0000009                   Miss Jerry  1894
# The Story of the Kelly Gang     tt0000574  The Story of the Kelly Gang  1906
#
#                             date_published                    genre  duration  \
# title
# Miss Jerry                      1894-10-09                  Romance        45
# The Story of the Kelly Gang     1906-12-26  Biography, Crime, Drama        70
#
#                                country language         director  \
# title
# Miss Jerry                         USA     None  Alexander Black
# The Story of the Kelly Gang  Australia     None     Charles Tait
#
#                                       writer  ...  \
# title                                         ...
# Miss Jerry                   Alexander Black  ...
# The Story of the Kelly Gang     Charles Tait  ...
#
#                                                                         actors  \
# title
# Miss Jerry                   Blanche Bayliss, William Courtenay, Chauncey D...
# The Story of the Kelly Gang  Elizabeth Tait, John Tait, Norman Campbell, Be...
#
#                                                                    description  \
# title
# Miss Jerry                   The adventures of a female reporter in the 1890s.
# The Story of the Kelly Gang  True story of notorious Australian outlaw Ned ...
#
#                             avg_vote  votes  budget usa_gross_income  \
# title
# Miss Jerry                       5.9    154     NaN              NaN
# The Story of the Kelly Gang      6.1    589  $ 2250              NaN
#
#                             worlwide_gross_income metascore  \
# title
# Miss Jerry                                    NaN       NaN
# The Story of the Kelly Gang                   NaN       NaN
#
#                              reviews_from_users  reviews_from_critics
# title
# Miss Jerry                                  1.0                   2.0
# The Story of the Kelly Gang                 7.0                   7.0
#
# [2 rows x 21 columns]

# %%
movies_df.columns
# Out:
# Index(['imdb_title_id', 'original_title', 'year', 'date_published', 'genre',
#        'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
movies_df.rename(columns = {'imdb_title_id':'Title_ID','original_title':'Title'},inplace = True)
movies_df.columns
# Out:
# Index(['Title_ID', 'Title', 'year', 'date_published', 'genre', 'duration',
#        'country', 'language', 'director', 'writer', 'production_company',
#        'actors', 'description', 'avg_vote', 'votes', 'budget',
#        'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
movies_df.columns =[col.lower() for col in movies_df]
movies_df.columns
# Out:
# Index(['title_id', 'title', 'year', 'date_published', 'genre', 'duration',
#        'country', 'language', 'director', 'writer', 'production_company',
#        'actors', 'description', 'avg_vote', 'votes', 'budget',
#        'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
movies_df.columns = [col.upper()for col  in movies_df]
movies_df.columns
# Out:
# Index(['TITLE_ID', 'TITLE', 'YEAR', 'DATE_PUBLISHED', 'GENRE', 'DURATION',
#        'COUNTRY', 'LANGUAGE', 'DIRECTOR', 'WRITER', 'PRODUCTION_COMPANY',
#        'ACTORS', 'DESCRIPTION', 'AVG_VOTE', 'VOTES', 'BUDGET',
#        'USA_GROSS_INCOME', 'WORLWIDE_GROSS_INCOME', 'METASCORE',
#        'REVIEWS_FROM_USERS', 'REVIEWS_FROM_CRITICS'],
#       dtype='object')

# %%
movies_df.isnull()
# Out:
#                                 TITLE_ID  TITLE   YEAR  DATE_PUBLISHED  GENRE  \
# title
# Miss Jerry                         False  False  False           False  False
# The Story of the Kelly Gang        False  False  False           False  False
# Den sorte drøm                     False  False  False           False  False
# Cleopatra                          False  False  False           False  False
# L'Inferno                          False  False  False           False  False
# ...                                  ...    ...    ...             ...    ...
# Le lion                            False  False  False           False  False
# De Beentjes van Sint-Hildegard     False  False  False           False  False
# Padmavyuhathile Abhimanyu          False  False  False           False  False
# Sokagin Çocuklari                  False  False  False           False  False
# La vida sense la Sara Amat         False  False  False           False  False
#
#                                 DURATION  COUNTRY  LANGUAGE  DIRECTOR  WRITER  \
# title
# Miss Jerry                         False    False     False     False   False
# The Story of the Kelly Gang        False    False     False     False   False
# Den sorte drøm                     False    False      True     False   False
# Cleopatra                          False    False     False     False   False
# L'Inferno                          False    False     False     False   False
# ...                                  ...      ...       ...       ...     ...
# Le lion                            False    False     False     False   False
# De Beentjes van Sint-Hildegard     False    False     False     False   False
# Padmavyuhathile Abhimanyu          False    False     False     False   False
# Sokagin Çocuklari                  False    False     False     False   False
# La vida sense la Sara Amat         False    False     False     False   False
#
#                                 ...  ACTORS  DESCRIPTION  AVG_VOTE  VOTES  \
# title                           ...
# Miss Jerry                      ...   False        False     False  False
# The Story of the Kelly Gang     ...   False        False     False  False
# Den sorte drøm                  ...   False        False     False  False
# Cleopatra                       ...   False        False     False  False
# L'Inferno                       ...   False        False     False  False
# ...                             ...     ...          ...       ...    ...
# Le lion                         ...   False        False     False  False
# De Beentjes van Sint-Hildegard  ...   False        False     False  False
# Padmavyuhathile Abhimanyu       ...   False         True     False  False
# Sokagin Çocuklari               ...   False         True     False  False
# La vida sense la Sara Amat      ...   False        False     False  False
#
#                                 BUDGET  USA_GROSS_INCOME  \
# title
# Miss Jerry                        True              True
# The Story of the Kelly Gang      False              True
# Den sorte drøm                    True              True
# Cleopatra                        False              True
# L'Inferno                         True              True
# ...                                ...               ...
# Le lion                           True              True
# De Beentjes van Sint-Hildegard    True              True
# Padmavyuhathile Abhimanyu         True              True
# Sokagin Çocuklari                 True              True
# La vida sense la Sara Amat        True              True
#
#                                 WORLWIDE_GROSS_INCOME  METASCORE  \
# title
# Miss Jerry                                       True       True
# The Story of the Kelly Gang                      True       True
# Den sorte drøm                                   True       True
# Cleopatra                                        True       True
# L'Inferno                                        True       True
# ...                                               ...        ...
# Le lion                                         False       True
# De Beentjes van Sint-Hildegard                  False       True
# Padmavyuhathile Abhimanyu                        True       True
# Sokagin Çocuklari                               False       True
# La vida sense la Sara Amat                      False       True
#
#                                 REVIEWS_FROM_USERS  REVIEWS_FROM_CRITICS
# title
# Miss Jerry                                   False                 False
# The Story of the Kelly Gang                  False                 False
# Den sorte drøm                               False                 False
# Cleopatra                                    False                 False
# L'Inferno                                    False                 False
# ...                                            ...                   ...
# Le lion                                       True                 False
# De Beentjes van Sint-Hildegard               False                 False
# Padmavyuhathile Abhimanyu                     True                  True
# Sokagin Çocuklari                             True                  True
# La vida sense la Sara Amat                    True                 False
#
# [85855 rows x 21 columns]

# %%
movies_df.isnull().sum()
# Out:
# TITLE_ID                     0
# TITLE                        0
# YEAR                         0
# DATE_PUBLISHED               0
# GENRE                        0
# DURATION                     0
# COUNTRY                     64
# LANGUAGE                   833
# DIRECTOR                    87
# WRITER                    1572
# PRODUCTION_COMPANY        4455
# ACTORS                      69
# DESCRIPTION               2115
# AVG_VOTE                     0
# VOTES                        0
# BUDGET                   62145
# USA_GROSS_INCOME         70529
# WORLWIDE_GROSS_INCOME    54839
# METASCORE                72550
# REVIEWS_FROM_USERS        7597
# REVIEWS_FROM_CRITICS     11797
# dtype: int64

# %%
movies_df.dropna()
# Out:
#                                 TITLE_ID                            TITLE  \
# title
# Metropolis                     tt0017136                       Metropolis
# Luci della città               tt0021749                      City Lights
# Tempi moderni                  tt0027977                     Modern Times
# Il bandito della Casbah        tt0029453                     Pépé le Moko
# Biancaneve e i sette nani      tt0029583  Snow White and the Seven Dwarfs
# ...                                  ...                              ...
# Impractical Jokers: The Movie  tt9208444    Impractical Jokers: The Movie
# Emma.                          tt9214832                            Emma.
# Jexi                           tt9354944                             Jexi
# Weathering with You            tt9426210                      Tenki no ko
# Cosa mi lasci di te            tt9779516                  I Still Believe
#
#                                YEAR DATE_PUBLISHED  \
# title
# Metropolis                     1927     1928-10-01
# Luci della città               1931     1931-04-02
# Tempi moderni                  1936     1937-03-12
# Il bandito della Casbah        1937     1937-10-22
# Biancaneve e i sette nani      1937     1938-11-30
# ...                             ...            ...
# Impractical Jokers: The Movie  2020     2020-02-28
# Emma.                          2020     2020-03-27
# Jexi                           2019     2019-10-11
# Weathering with You            2019     2019-10-14
# Cosa mi lasci di te            2020     2020-03-19
#
#                                                     GENRE  DURATION  \
# title
# Metropolis                                  Drama, Sci-Fi       153
# Luci della città                   Comedy, Drama, Romance        87
# Tempi moderni                       Comedy, Drama, Family        87
# Il bandito della Casbah             Crime, Drama, Romance        94
# Biancaneve e i sette nani      Animation, Family, Fantasy        83
# ...                                                   ...       ...
# Impractical Jokers: The Movie                      Comedy        92
# Emma.                                       Comedy, Drama       124
# Jexi                                      Comedy, Romance        84
# Weathering with You              Animation, Drama, Family       112
# Cosa mi lasci di te               Biography, Drama, Music       116
#
#                                     COUNTRY        LANGUAGE  \
# title
# Metropolis                          Germany          German
# Luci della città                        USA         English
# Tempi moderni                           USA         English
# Il bandito della Casbah              France  French, Arabic
# Biancaneve e i sette nani               USA         English
# ...                                     ...             ...
# Impractical Jokers: The Movie           USA         English
# Emma.                                    UK         English
# Jexi                            USA, Canada         English
# Weathering with You            Japan, China        Japanese
# Cosa mi lasci di te                     USA         English
#
#                                                    DIRECTOR  \
# title
# Metropolis                                       Fritz Lang
# Luci della città                            Charles Chaplin
# Tempi moderni                               Charles Chaplin
# Il bandito della Casbah                     Julien Duvivier
# Biancaneve e i sette nani      William Cottrell, David Hand
# ...                                                     ...
# Impractical Jokers: The Movie                  Chris Henchy
# Emma.                                       Autumn de Wilde
# Jexi                                 Jon Lucas, Scott Moore
# Weathering with You                          Makoto Shinkai
# Cosa mi lasci di te                 Andrew Erwin, Jon Erwin
#
#                                                          WRITER  ...  \
# title                                                            ...
# Metropolis                     Thea von Harbou, Thea von Harbou  ...
# Luci della città                                Charles Chaplin  ...
# Tempi moderni                                   Charles Chaplin  ...
# Il bandito della Casbah        Henri La Barthe, Henri La Barthe  ...
# Biancaneve e i sette nani            Jacob Grimm, Wilhelm Grimm  ...
# ...                                                         ...  ...
# Impractical Jokers: The Movie           Chris Henchy, Joe Gatto  ...
# Emma.                               Eleanor Catton, Jane Austen  ...
# Jexi                                     Jon Lucas, Scott Moore  ...
# Weathering with You                              Makoto Shinkai  ...
# Cosa mi lasci di te                      Jeremy Camp, Jon Erwin  ...
#
#                                                                           ACTORS  \
# title
# Metropolis                     Alfred Abel, Gustav Fröhlich, Rudolf Klein-Rog...
# Luci della città               Virginia Cherrill, Florence Lee, Harry Myers, ...
# Tempi moderni                  Charles Chaplin, Paulette Goddard, Henry Bergm...
# Il bandito della Casbah        Jean Gabin, Gabriel Gabrio, Saturnin Fabre, Fe...
# Biancaneve e i sette nani      Roy Atwell, Stuart Buchanan, Adriana Caselotti...
# ...                                                                          ...
# Impractical Jokers: The Movie  Paula Abdul, Joe Gatto, James Murray, Brian Qu...
# Emma.                          Anya Taylor-Joy, Angus Imrie, Letty Thomas, Ge...
# Jexi                           Adam Devine, Alexandra Shipp, Rose Byrne, Ron ...
# Weathering with You            Kotaro Daigo, Nana Mori, Shun Oguri, Sei Hirai...
# Cosa mi lasci di te            K.J. Apa, Britt Robertson, Nathan Parsons, Gar...
#
#                                                                      DESCRIPTION  \
# title
# Metropolis                     In a futuristic city sharply divided between t...
# Luci della città               With the aid of a wealthy erratic tippler, a d...
# Tempi moderni                  The Tramp struggles to live in modern industri...
# Il bandito della Casbah        A wanted gangster is both king and prisoner of...
# Biancaneve e i sette nani      Exiled into the dangerous forest by her wicked...
# ...                                                                          ...
# Impractical Jokers: The Movie  The story of a humiliating high school mishap ...
# Emma.                          In 1800s England, a well meaning but selfish y...
# Jexi                           A comedy about what can happen when you love y...
# Weathering with You            A high-school boy who has run away to Tokyo be...
# Cosa mi lasci di te            The true-life story of Christian music star Je...
#
#                               AVG_VOTE   VOTES       BUDGET USA_GROSS_INCOME  \
# title
# Metropolis                         8.3  156076  DEM 6000000        $ 1236166
# Luci della città                   8.5  162668    $ 1500000          $ 19181
# Tempi moderni                      8.5  211250    $ 1500000         $ 163577
# Il bandito della Casbah            7.7    6180      $ 60000         $ 155895
# Biancaneve e i sette nani          7.6  177157    $ 1499000      $ 184925486
# ...                                ...     ...          ...              ...
# Impractical Jokers: The Movie      5.9    4105    $ 3000000       $ 10691091
# Emma.                              6.7   19858   $ 10000000       $ 10055355
# Jexi                               6.1   17038    $ 5000000        $ 6546159
# Weathering with You                7.6   16277   $ 11100000        $ 7798743
# Cosa mi lasci di te                6.5    6196   $ 12000000        $ 9868521
#
#                               WORLWIDE_GROSS_INCOME METASCORE  \
# title
# Metropolis                                $ 1349711      98.0
# Luci della città                            $ 46008      99.0
# Tempi moderni                              $ 457688      96.0
# Il bandito della Casbah                    $ 155895      98.0
# Biancaneve e i sette nani               $ 184925486      95.0
# ...                                             ...       ...
# Impractical Jokers: The Movie            $ 10691091      39.0
# Emma.                                    $ 25659965      71.0
# Jexi                                      $ 9341824      39.0
# Weathering with You                     $ 193176979      72.0
# Cosa mi lasci di te                      $ 13681524      41.0
#
#                                REVIEWS_FROM_USERS  REVIEWS_FROM_CRITICS
# title
# Metropolis                                  495.0                 208.0
# Luci della città                            295.0                 122.0
# Tempi moderni                               307.0                 115.0
# Il bandito della Casbah                      46.0                  55.0
# Biancaneve e i sette nani                   260.0                 173.0
# ...                                           ...                   ...
# Impractical Jokers: The Movie               152.0                  17.0
# Emma.                                       314.0                 188.0
# Jexi                                        234.0                  42.0
# Weathering with You                         177.0                 110.0
# Cosa mi lasci di te                         151.0                  52.0
#
# [6616 rows x 21 columns]

# %%
movies_df.dropna(axis=1)
# Out:
#                                  TITLE_ID                           TITLE  \
# title
# Miss Jerry                      tt0000009                      Miss Jerry
# The Story of the Kelly Gang     tt0000574     The Story of the Kelly Gang
# Den sorte drøm                  tt0001892                  Den sorte drøm
# Cleopatra                       tt0002101                       Cleopatra
# L'Inferno                       tt0002130                       L'Inferno
# ...                                   ...                             ...
# Le lion                         tt9908390                         Le lion
# De Beentjes van Sint-Hildegard  tt9911196  De Beentjes van Sint-Hildegard
# Padmavyuhathile Abhimanyu       tt9911774       Padmavyuhathile Abhimanyu
# Sokagin Çocuklari               tt9914286               Sokagin Çocuklari
# La vida sense la Sara Amat      tt9914942      La vida sense la Sara Amat
#
#                                 YEAR DATE_PUBLISHED  \
# title
# Miss Jerry                      1894     1894-10-09
# The Story of the Kelly Gang     1906     1906-12-26
# Den sorte drøm                  1911     1911-08-19
# Cleopatra                       1912     1912-11-13
# L'Inferno                       1911     1911-03-06
# ...                              ...            ...
# Le lion                         2020     2020-01-29
# De Beentjes van Sint-Hildegard  2020     2020-02-13
# Padmavyuhathile Abhimanyu       2019     2019-03-08
# Sokagin Çocuklari               2019     2019-03-15
# La vida sense la Sara Amat      2019     2020-02-05
#
#                                                     GENRE  DURATION  AVG_VOTE  \
# title
# Miss Jerry                                        Romance        45       5.9
# The Story of the Kelly Gang       Biography, Crime, Drama        70       6.1
# Den sorte drøm                                      Drama        53       5.8
# Cleopatra                                  Drama, History       100       5.2
# L'Inferno                       Adventure, Drama, Fantasy        68       7.0
# ...                                                   ...       ...       ...
# Le lion                                            Comedy        95       5.3
# De Beentjes van Sint-Hildegard              Comedy, Drama       103       7.7
# Padmavyuhathile Abhimanyu                           Drama       130       7.9
# Sokagin Çocuklari                           Drama, Family        98       6.4
# La vida sense la Sara Amat                          Drama        74       6.7
#
#                                 VOTES
# title
# Miss Jerry                        154
# The Story of the Kelly Gang       589
# Den sorte drøm                    188
# Cleopatra                         446
# L'Inferno                        2237
# ...                               ...
# Le lion                           398
# De Beentjes van Sint-Hildegard    724
# Padmavyuhathile Abhimanyu         265
# Sokagin Çocuklari                 194
# La vida sense la Sara Amat        102
#
# [85855 rows x 8 columns]

# %%
duration = movies_df['DURATION']
duration
# Out:
# title
# Miss Jerry                         45
# The Story of the Kelly Gang        70
# Den sorte drøm                     53
# Cleopatra                         100
# L'Inferno                          68
#                                  ...
# Le lion                            95
# De Beentjes van Sint-Hildegard    103
# Padmavyuhathile Abhimanyu         130
# Sokagin Çocuklari                  98
# La vida sense la Sara Amat         74
# Name: DURATION, Length: 85855, dtype: int64

# %%
##Week 5

# %%
duration.head()
# Out:
# title
# Miss Jerry                      45
# The Story of the Kelly Gang     70
# Den sorte drøm                  53
# Cleopatra                      100
# L'Inferno                       68
# Name: DURATION, dtype: int64

# %%
durationmean = duration.mean()
durationmean
# Out:
# 100.35141808863781

# %%
duration.fillna(durationmean, inplace = True)

# %%
movies_df.isnull().sum()
# Out:
# TITLE_ID                     0
# TITLE                        0
# YEAR                         0
# DATE_PUBLISHED               0
# GENRE                        0
# DURATION                     0
# COUNTRY                     64
# LANGUAGE                   833
# DIRECTOR                    87
# WRITER                    1572
# PRODUCTION_COMPANY        4455
# ACTORS                      69
# DESCRIPTION               2115
# AVG_VOTE                     0
# VOTES                        0
# BUDGET                   62145
# USA_GROSS_INCOME         70529
# WORLWIDE_GROSS_INCOME    54839
# METASCORE                72550
# REVIEWS_FROM_USERS        7597
# REVIEWS_FROM_CRITICS     11797
# dtype: int64

# %%
movies_df.describe()
# Out:
#            DURATION      AVG_VOTE         VOTES     METASCORE  \
# count  85855.000000  85855.000000  8.585500e+04  13305.000000
# mean     100.351418      5.898656  9.493490e+03     55.896881
# std       22.553848      1.234987  5.357436e+04     17.784874
# min       41.000000      1.000000  9.900000e+01      1.000000
# 25%       88.000000      5.200000  2.050000e+02     43.000000
# 50%       96.000000      6.100000  4.840000e+02     57.000000
# 75%      108.000000      6.800000  1.766500e+03     69.000000
# max      808.000000      9.900000  2.278845e+06    100.000000
#
#        REVIEWS_FROM_USERS  REVIEWS_FROM_CRITICS
# count        78258.000000          74058.000000
# mean            46.040826             27.479989
# std            178.511411             58.339158
# min              1.000000              1.000000
# 25%              4.000000              3.000000
# 50%              9.000000              8.000000
# 75%             27.000000             23.000000
# max          10472.000000            999.000000

# %%
desc = movies_df['YEAR'].describe()
desc
# Out:
# count     85855
# unique      168
# top        2017
# freq       3223
# Name: YEAR, dtype: object

# %%
movies_df.corr()
# Out:
#                       DURATION  AVG_VOTE     VOTES  METASCORE  \
# DURATION              1.000000  0.242432  0.125618   0.210531
# AVG_VOTE              0.242432  1.000000  0.166972   0.691338
# VOTES                 0.125618  0.166972  1.000000   0.194730
# METASCORE             0.210531  0.691338  0.194730   1.000000
# REVIEWS_FROM_USERS    0.130836  0.138185  0.766237   0.126131
# REVIEWS_FROM_CRITICS  0.135465  0.200526  0.671635   0.236107
#
#                       REVIEWS_FROM_USERS  REVIEWS_FROM_CRITICS
# DURATION                        0.130836              0.135465
# AVG_VOTE                        0.138185              0.200526
# VOTES                           0.766237              0.671635
# METASCORE                       0.126131              0.236107
# REVIEWS_FROM_USERS              1.000000              0.671634
# REVIEWS_FROM_CRITICS            0.671634              1.000000

# %%
prom = movies_df.iloc[1]
prom
# Out:
# TITLE_ID                                                         tt0000574
# TITLE                                          The Story of the Kelly Gang
# YEAR                                                                  1906
# DATE_PUBLISHED                                                  1906-12-26
# GENRE                                              Biography, Crime, Drama
# DURATION                                                                70
# COUNTRY                                                          Australia
# LANGUAGE                                                              None
# DIRECTOR                                                      Charles Tait
# WRITER                                                        Charles Tait
# PRODUCTION_COMPANY                                          J. and N. Tait
# ACTORS                   Elizabeth Tait, John Tait, Norman Campbell, Be...
# DESCRIPTION              True story of notorious Australian outlaw Ned ...
# AVG_VOTE                                                               6.1
# VOTES                                                                  589
# BUDGET                                                              $ 2250
# USA_GROSS_INCOME                                                       NaN
# WORLWIDE_GROSS_INCOME                                                  NaN
# METASCORE                                                              NaN
# REVIEWS_FROM_USERS                                                       7
# REVIEWS_FROM_CRITICS                                                     7
# Name: The Story of the Kelly Gang, dtype: object

# %%
movie_subset = movies_df.loc['Atlantis':'Cabiria']

movie_subset = movies_df.iloc[1:4]

movie_subset
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-10c8482c488c> in <module>
# ----> 1 movie_subset = movies_df.loc['Atlantis':'Cabiria']
#       2
#       3 movie_subset = movies_df.iloc[1:4]
#       4
#       5 movie_subset
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1795         if isinstance(key, slice):
#    1796             self._validate_key(key, axis)
# -> 1797             return self._get_slice_axis(key, axis=axis)
#    1798         elif com.is_bool_indexer(key):
#    1799             return self._getbool_axis(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1452         labels = obj._get_axis(axis)
#    1453         indexer = labels.slice_indexer(
# -> 1454             slice_obj.start, slice_obj.stop, slice_obj.step, kind=self.name
#    1455         )
#    1456
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    5032         slice(1, 3)
#    5033         """
# -> 5034         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    5035
#    5036         # return a slice
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    5246         start_slice = None
#    5247         if start is not None:
# -> 5248             start_slice = self.get_slice_bound(start, "left", kind)
#    5249         if start_slice is None:
#    5250             start_slice = 0
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5180                 raise KeyError(
#    5181                     "Cannot get %s slice bound for non-unique "
# -> 5182                     "label: %r" % (side, original_label)
#    5183                 )
#    5184
#
# KeyError: "Cannot get left slice bound for non-unique label: 'Atlantis'"

# %%
condition = (movies_df['DIRECTOR'] == "Louis Feuillade")
condition.head()
# Out:
# title
# Miss Jerry                     False
# The Story of the Kelly Gang    False
# Den sorte drøm                 False
# Cleopatra                      False
# L'Inferno                      False
# Name: DIRECTOR, dtype: bool

# %%
movies_df[movies_df['DIRECTOR'] == "Louis Feuillade"].head()
# Out:
#                                         TITLE_ID  \
# title
# Fantômas - À l'ombre de la guillotine  tt0002844
# Juve contre Fantômas                   tt0003037
# Le mort qui tue                        tt0003165
# Fantômas contre Fantômas               tt0003930
# I vampiri                              tt0006206
#
#                                                                        TITLE  \
# title
# Fantômas - À l'ombre de la guillotine  Fantômas - À l'ombre de la guillotine
# Juve contre Fantômas                                    Juve contre Fantômas
# Le mort qui tue                                              Le mort qui tue
# Fantômas contre Fantômas                            Fantômas contre Fantômas
# I vampiri                                                       Les vampires
#
#                                        YEAR DATE_PUBLISHED  \
# title
# Fantômas - À l'ombre de la guillotine  1913     1913-05-12
# Juve contre Fantômas                   1913     1913-09-08
# Le mort qui tue                        1913     1913-11-06
# Fantômas contre Fantômas               1914     1914-01-10
# I vampiri                              1915     1915-11-13
#
#                                                           GENRE  DURATION  \
# title
# Fantômas - À l'ombre de la guillotine              Crime, Drama        54
# Juve contre Fantômas                               Crime, Drama        61
# Le mort qui tue                           Crime, Drama, Mystery        90
# Fantômas contre Fantômas                           Crime, Drama        59
# I vampiri                              Action, Adventure, Crime       421
#
#                                       COUNTRY LANGUAGE         DIRECTOR  \
# title
# Fantômas - À l'ombre de la guillotine  France   French  Louis Feuillade
# Juve contre Fantômas                   France   French  Louis Feuillade
# Le mort qui tue                        France   French  Louis Feuillade
# Fantômas contre Fantômas               France   French  Louis Feuillade
# I vampiri                              France   French  Louis Feuillade
#
#                                                                WRITER  ...  \
# title                                                                  ...
# Fantômas - À l'ombre de la guillotine  Marcel Allain, Louis Feuillade  ...
# Juve contre Fantômas                   Marcel Allain, Louis Feuillade  ...
# Le mort qui tue                        Marcel Allain, Louis Feuillade  ...
# Fantômas contre Fantômas               Marcel Allain, Louis Feuillade  ...
# I vampiri                                             Louis Feuillade  ...
#
#                                                                                   ACTORS  \
# title
# Fantômas - À l'ombre de la guillotine  René Navarre, Edmund Breon, Georges Melchior, ...
# Juve contre Fantômas                   René Navarre, Edmund Breon, Georges Melchior, ...
# Le mort qui tue                        René Navarre, Edmund Breon, Georges Melchior, ...
# Fantômas contre Fantômas               René Navarre, Georges Melchior, Laurent Morléa...
# I vampiri                              Musidora, Édouard Mathé, Marcel Lévesque, Jean...
#
#                                                                              DESCRIPTION  \
# title
# Fantômas - À l'ombre de la guillotine  Inspector Juve is tasked to investigate and ca...
# Juve contre Fantômas                   In Part Two of Louis Feuillade's 5 1/2-hour ep...
# Le mort qui tue                        After a body disappears from inside the prison...
# Fantômas contre Fantômas               The mystery of the drama is the appearance of ...
# I vampiri                              An intrepid reporter and his loyal friend batt...
#
#                                       AVG_VOTE  VOTES  BUDGET  \
# title
# Fantômas - À l'ombre de la guillotine      7.0   1944     NaN
# Juve contre Fantômas                       7.0   1349     NaN
# Le mort qui tue                            7.0   1050     NaN
# Fantômas contre Fantômas                   6.9   1161     NaN
# I vampiri                                  7.3   4166     NaN
#
#                                       USA_GROSS_INCOME WORLWIDE_GROSS_INCOME  \
# title
# Fantômas - À l'ombre de la guillotine              NaN                   NaN
# Juve contre Fantômas                               NaN                   NaN
# Le mort qui tue                                    NaN                   NaN
# Fantômas contre Fantômas                           NaN                   NaN
# I vampiri                                          NaN                   NaN
#
#                                       METASCORE  REVIEWS_FROM_USERS  \
# title
# Fantômas - À l'ombre de la guillotine       NaN                 9.0
# Juve contre Fantômas                        NaN                 8.0
# Le mort qui tue                             NaN                 6.0
# Fantômas contre Fantômas                    NaN                 5.0
# I vampiri                                   NaN                25.0
#
#                                        REVIEWS_FROM_CRITICS
# title
# Fantômas - À l'ombre de la guillotine                  28.0
# Juve contre Fantômas                                   23.0
# Le mort qui tue                                        18.0
# Fantômas contre Fantômas                               18.0
# I vampiri                                              53.0
#
# [5 rows x 21 columns]

# %%
movies_df[movies_df['DURATION'] >= 71].head(3)
# Out:
#                  TITLE_ID           TITLE  YEAR DATE_PUBLISHED  \
# title
# Cleopatra       tt0002101       Cleopatra  1912     1912-11-13
# Madame DuBarry  tt0002423  Madame DuBarry  1919     1919-11-26
# Quo Vadis?      tt0002445      Quo Vadis?  1913     1913-03-01
#
#                                     GENRE  DURATION  COUNTRY LANGUAGE  \
# title
# Cleopatra                  Drama, History       100      USA  English
# Madame DuBarry  Biography, Drama, Romance        85  Germany   German
# Quo Vadis?                 Drama, History       120    Italy  Italian
#
#                           DIRECTOR                               WRITER  ...  \
# title                                                                    ...
# Cleopatra       Charles L. Gaskill                     Victorien Sardou  ...
# Madame DuBarry      Ernst Lubitsch            Norbert Falk, Hanns Kräly  ...
# Quo Vadis?         Enrico Guazzoni  Henryk Sienkiewicz, Enrico Guazzoni  ...
#
#                                                            ACTORS  \
# title
# Cleopatra       Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# Madame DuBarry  Pola Negri, Emil Jannings, Harry Liedtke, Edua...
# Quo Vadis?      Amleto Novelli, Gustavo Serena, Carlo Cattaneo...
#
#                                                       DESCRIPTION AVG_VOTE  \
# title
# Cleopatra       The fabled queen of Egypt's affair with Roman ...      5.2
# Madame DuBarry  The story of Madame DuBarry, the mistress of L...      6.8
# Quo Vadis?      An epic Italian film "Quo Vadis" influenced ma...      6.2
#
#                 VOTES     BUDGET USA_GROSS_INCOME WORLWIDE_GROSS_INCOME  \
# title
# Cleopatra         446    $ 45000              NaN                   NaN
# Madame DuBarry    753        NaN              NaN                   NaN
# Quo Vadis?        273  ITL 45000              NaN                   NaN
#
#                METASCORE  REVIEWS_FROM_USERS  REVIEWS_FROM_CRITICS
# title
# Cleopatra            NaN                25.0                   3.0
# Madame DuBarry       NaN                12.0                   9.0
# Quo Vadis?           NaN                 7.0                   5.0
#
# [3 rows x 21 columns]

# %%
movies_df[(movies_df['DIRECTOR'] == 'Charles Tait') | (movies_df['DIRECTOR'] == 'Christopher Nolan')].head()
# Out:
#                               TITLE_ID                        TITLE  YEAR  \
# title
# The Story of the Kelly Gang  tt0000574  The Story of the Kelly Gang  1906
# Following                    tt0154506                    Following  1998
# Memento                      tt0209144                      Memento  2000
# Insomnia                     tt0278504                     Insomnia  2002
# Batman Begins                tt0372784                Batman Begins  2005
#
#                             DATE_PUBLISHED                     GENRE  \
# title
# The Story of the Kelly Gang     1906-12-26   Biography, Crime, Drama
# Following                       2000-08-25  Crime, Mystery, Thriller
# Memento                         2001-01-19         Mystery, Thriller
# Insomnia                        2002-11-08  Drama, Mystery, Thriller
# Batman Begins                   2005-06-17         Action, Adventure
#
#                              DURATION    COUNTRY           LANGUAGE  \
# title
# The Story of the Kelly Gang        70  Australia               None
# Following                          69         UK            English
# Memento                           113        USA            English
# Insomnia                          118    USA, UK            English
# Batman Begins                     140    USA, UK  English, Mandarin
#
#                                       DIRECTOR  \
# title
# The Story of the Kelly Gang       Charles Tait
# Following                    Christopher Nolan
# Memento                      Christopher Nolan
# Insomnia                     Christopher Nolan
# Batman Begins                Christopher Nolan
#
#                                                         WRITER  ...  \
# title                                                           ...
# The Story of the Kelly Gang                       Charles Tait  ...
# Following                                    Christopher Nolan  ...
# Memento                      Christopher Nolan, Jonathan Nolan  ...
# Insomnia                      Hillary Seitz, Nikolaj Frobenius  ...
# Batman Begins                         Bob Kane, David S. Goyer  ...
#
#                                                                         ACTORS  \
# title
# The Story of the Kelly Gang  Elizabeth Tait, John Tait, Norman Campbell, Be...
# Following                    Jeremy Theobald, Alex Haw, Lucy Russell, John ...
# Memento                      Guy Pearce, Carrie-Anne Moss, Joe Pantoliano, ...
# Insomnia                     Al Pacino, Martin Donovan, Oliver 'Ole' Zemen,...
# Batman Begins                Christian Bale, Michael Caine, Liam Neeson, Ka...
#
#                                                                    DESCRIPTION  \
# title
# The Story of the Kelly Gang  True story of notorious Australian outlaw Ned ...
# Following                    A young writer who follows strangers for mater...
# Memento                      A man with short-term memory loss attempts to ...
# Insomnia                     Two Los Angeles homicide detectives are dispat...
# Batman Begins                After training with his mentor, Batman begins ...
#
#                             AVG_VOTE    VOTES       BUDGET USA_GROSS_INCOME  \
# title
# The Story of the Kelly Gang      6.1      589       $ 2250              NaN
# Following                        7.5    84550       $ 6000          $ 48482
# Memento                          8.4  1098879    $ 9000000       $ 25544867
# Insomnia                         7.2   269304   $ 46000000       $ 67355513
# Batman Begins                    8.2  1278075  $ 150000000      $ 206852432
#
#                             WORLWIDE_GROSS_INCOME METASCORE  \
# title
# The Story of the Kelly Gang                   NaN       NaN
# Following                                 $ 48482      60.0
# Memento                                $ 39970386      80.0
# Insomnia                              $ 113758770      78.0
# Batman Begins                         $ 373654966      70.0
#
#                              REVIEWS_FROM_USERS  REVIEWS_FROM_CRITICS
# title
# The Story of the Kelly Gang                 7.0                   7.0
# Following                                 208.0                 137.0
# Memento                                  2278.0                 213.0
# Insomnia                                  694.0                 113.0
# Batman Begins                            2911.0                 324.0
#
# [5 rows x 21 columns]
